# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
import seaborn as sns
import prince
# %matplotlib inline

# %%
df=pd.read_excel('./../myproj/Survey_final_1.xlsx')

# %%
X=df[['Is it difficult to get essentials(food/medicine)?',
       'What is your gender?', 'How you ever felt symptoms of COVID?',
       'Do you have any of the following conditions?',
       'During the lockdown have you been doing more household work?',
       'Have you or anyone you know have corona virus/recovered from COVID/been tested for COVID?',
       'How often do you use masks/hand sanitizers(per day)?',
       'Do you feel like you have wasted your time during the lock down or have you ever felt pressurized by your peer’s accomplishments during the lock down?',
       'How often do you eat outside food? (per week)',
       'Are you in a containment zone?',
       'Are you stuck somewhere alone without support from friends or family?',
       'Do you have children less than 3 yrs, or elders 65+ at your house?',
       'Have you ever felt afraid or anxious to go to hospital during this pandemic?',
       'Has your sleep cycle changed drastically?',
       'Have you felt frustrated by having your activities, major life events or opportunities affected by the virus?',
       'Is someone from your family in the medical field everyday?',
       'Do you have online classes/assignments/assessments/tests?',
       'Did you face a pay cut/job loss/take another job to cover expenses?',
       'How often do you leave your house?(per week)',
       'How often do you interact with people outside your house(friends,neighbors etc.,)?',
       'Have you taken any medication to prevent corona(Chloroquine or kabasura kudineer) or any medication to increase your immunity?',
       'Have you been affected by not being able to visit religious places?',
       'Do you miss hanging out with people outside of your house?']]

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(X, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
y_est=cluster.fit_predict(X)

# %%
X['cluster'] = y_est
# Out:
# <ipython-input-32-2c3484695a43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = y_est

# %%
X["cluster"].value_counts()
# Out:
# 0    152
# 2    123
# 3    101
# 1     63
# Name: cluster, dtype: int64

# %%
cluster_0=X[X['cluster']==0]
cluster_1=X[X['cluster']==1]
cluster_2=X[X['cluster']==2]
cluster_3=X[X['cluster']==3]

# %%
cluster_0['Is it difficult to get essentials(food/medicine)?'].plot.hist()

# %%
cluster_1['Is it difficult to get essentials(food/medicine)?'].plot.hist()

# %%
cluster_2['Is it difficult to get essentials(food/medicine)?'].plot.hist()

# %%
cluster_3['Is it difficult to get essentials(food/medicine)?'].plot.hist()

# %%
cluster_0['What is your gender?'].plot.hist()

# %%
cluster_1['What is your gender?'].plot.hist()

# %%
cluster_2['What is your gender?'].plot.hist()

# %%
cluster_3['What is your gender?'].plot.hist()

# %%
cluster_0['How you ever felt symptoms of COVID?'].plot.hist()

# %%
cluster_1['How you ever felt symptoms of COVID?'].plot.hist()

# %%
cluster_2['How you ever felt symptoms of COVID?'].plot.hist()

# %%
cluster_3['How you ever felt symptoms of COVID?'].plot.hist()

# %%
cluster_0['Do you have any of the following conditions?'].plot.hist()

# %%
cluster_1['Do you have any of the following conditions?'].plot.hist()

# %%
cluster_2['Do you have any of the following conditions?'].plot.hist()

# %%
cluster_3['Do you have any of the following conditions?'].plot.hist()

# %%
cluster_0['During the lockdown have you been doing more household work?'].plot.hist()

# %%
cluster_1['During the lockdown have you been doing more household work?'].plot.hist()

# %%
cluster_2['During the lockdown have you been doing more household work?'].plot.hist()

# %%
cluster_3['During the lockdown have you been doing more household work?'].plot.hist()

# %%
cluster_0['Have you or anyone you know have corona virus/recovered from COVID/been tested for COVID?'].plot.hist()

# %%
cluster_1['Have you or anyone you know have corona virus/recovered from COVID/been tested for COVID?'].plot.hist()

# %%
cluster_2['Have you or anyone you know have corona virus/recovered from COVID/been tested for COVID?'].plot.hist()

# %%
cluster_3['Have you or anyone you know have corona virus/recovered from COVID/been tested for COVID?'].plot.hist()

# %%
plt.hist(cluster_0['How often do you use masks/hand sanitizers(per day)?'], label="cluster0")
plt.hist(cluster_1['How often do you use masks/hand sanitizers(per day)?'], label="cluster1")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='upper right')

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['How often do you use masks/hand sanitizers(per day)?'])
b_heights, b_bins = np.histogram(cluster_1['How often do you use masks/hand sanitizers(per day)?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['How often do you use masks/hand sanitizers(per day)?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['How often do you use masks/hand sanitizers(per day)?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Do you feel like you have wasted your time during the lock down or have you ever felt pressurized by your peer’s accomplishments during the lock down?'])
b_heights, b_bins = np.histogram(cluster_1['Do you feel like you have wasted your time during the lock down or have you ever felt pressurized by your peer’s accomplishments during the lock down?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Do you feel like you have wasted your time during the lock down or have you ever felt pressurized by your peer’s accomplishments during the lock down?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Do you feel like you have wasted your time during the lock down or have you ever felt pressurized by your peer’s accomplishments during the lock down?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['How often do you eat outside food? (per week)'])
b_heights, b_bins = np.histogram(cluster_1['How often do you eat outside food? (per week)'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['How often do you eat outside food? (per week)'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['How often do you eat outside food? (per week)'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Are you in a containment zone?'])
b_heights, b_bins = np.histogram(cluster_1['Are you in a containment zone?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Are you in a containment zone?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Are you in a containment zone?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Are you stuck somewhere alone without support from friends or family?'])
b_heights, b_bins = np.histogram(cluster_1['Are you stuck somewhere alone without support from friends or family?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Are you stuck somewhere alone without support from friends or family?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Are you stuck somewhere alone without support from friends or family?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Do you have children less than 3 yrs, or elders 65+ at your house?'])
b_heights, b_bins = np.histogram(cluster_1['Do you have children less than 3 yrs, or elders 65+ at your house?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Do you have children less than 3 yrs, or elders 65+ at your house?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Do you have children less than 3 yrs, or elders 65+ at your house?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Have you ever felt afraid or anxious to go to hospital during this pandemic?'])
b_heights, b_bins = np.histogram(cluster_1['Have you ever felt afraid or anxious to go to hospital during this pandemic?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Have you ever felt afraid or anxious to go to hospital during this pandemic?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Have you ever felt afraid or anxious to go to hospital during this pandemic?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Has your sleep cycle changed drastically?'])
b_heights, b_bins = np.histogram(cluster_1['Has your sleep cycle changed drastically?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Has your sleep cycle changed drastically?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Has your sleep cycle changed drastically?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Have you felt frustrated by having your activities, major life events or opportunities affected by the virus?'])
b_heights, b_bins = np.histogram(cluster_1['Have you felt frustrated by having your activities, major life events or opportunities affected by the virus?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Have you felt frustrated by having your activities, major life events or opportunities affected by the virus?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Have you felt frustrated by having your activities, major life events or opportunities affected by the virus?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Is someone from your family in the medical field everyday?'])
b_heights, b_bins = np.histogram(cluster_1['Is someone from your family in the medical field everyday?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Is someone from your family in the medical field everyday?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Is someone from your family in the medical field everyday?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Do you have online classes/assignments/assessments/tests?'])
b_heights, b_bins = np.histogram(cluster_1['Do you have online classes/assignments/assessments/tests?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Do you have online classes/assignments/assessments/tests?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Do you have online classes/assignments/assessments/tests?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Did you face a pay cut/job loss/take another job to cover expenses?'])
b_heights, b_bins = np.histogram(cluster_1['Did you face a pay cut/job loss/take another job to cover expenses?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Did you face a pay cut/job loss/take another job to cover expenses?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Did you face a pay cut/job loss/take another job to cover expenses?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['How often do you leave your house?(per week)'])
b_heights, b_bins = np.histogram(cluster_1['How often do you leave your house?(per week)'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['How often do you leave your house?(per week)'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['How often do you leave your house?(per week)'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['How often do you interact with people outside your house(friends,neighbors etc.,)?'])
b_heights, b_bins = np.histogram(cluster_1['How often do you interact with people outside your house(friends,neighbors etc.,)?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['How often do you interact with people outside your house(friends,neighbors etc.,)?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['How often do you interact with people outside your house(friends,neighbors etc.,)?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Have you taken any medication to prevent corona(Chloroquine or kabasura kudineer) or any medication to increase your immunity?'])
b_heights, b_bins = np.histogram(cluster_1['Have you taken any medication to prevent corona(Chloroquine or kabasura kudineer) or any medication to increase your immunity?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Have you taken any medication to prevent corona(Chloroquine or kabasura kudineer) or any medication to increase your immunity?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Have you taken any medication to prevent corona(Chloroquine or kabasura kudineer) or any medication to increase your immunity?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Have you been affected by not being able to visit religious places?'])
b_heights, b_bins = np.histogram(cluster_1['Have you been affected by not being able to visit religious places?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Have you been affected by not being able to visit religious places?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Have you been affected by not being able to visit religious places?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0['Do you miss hanging out with people outside of your house?'])
b_heights, b_bins = np.histogram(cluster_1['Do you miss hanging out with people outside of your house?'], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2['Do you miss hanging out with people outside of your house?'], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3['Do you miss hanging out with people outside of your house?'], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow')
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()

a_heights, a_bins = np.histogram(cluster_0[])
b_heights, b_bins = np.histogram(cluster_1[], bins=a_bins)
c_heights, c_bins = np.histogram(cluster_2[], bins=b_bins)
d_heights, d_bins = np.histogram(cluster_3[], bins=c_bins)
width = (a_bins[1] - a_bins[0])

ax.bar(a_bins[:-1], a_heights, width=width, facecolor='cornflowerblue')
ax.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen')
ax.bar(c_bins[:-1]+width+width, c_heights, width=width, facecolor='red')
ax.bar(d_bins[:-1]+width+width+width, d_heights, width=width, facecolor='yellow'
